# %%
import pandas as pd
from pathlib import Path

csv_path = Path("UpdatedResumeDataSet.csv")
if not csv_path.exists():
    csv_path = Path(r"C:\Users\Acer\Documents\Programs\ResuMatch\Dataset\UpdatedResumeDataSet.csv")

try:
    df = pd.read_csv(csv_path)
except UnicodeDecodeError:
    df = pd.read_csv(csv_path, encoding="latin1")

print(df.shape)
print(df.columns.tolist())
print(df.head(3))
print(df.isnull().sum())
print(df['Category'].value_counts())
# Out:
# (962, 2)
# ['Category', 'Resume']
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# Category    0
# Resume      0
# dtype: int64
# Category
# Java Developer               84
# Testing                      70
# DevOps Engineer              55
# Python Developer             48
# Web Designing                45
# HR                           44
# Hadoop                       42
# Data Science                 40
# Mechanical Engineer          40
# Sales                        40
# Operations Manager           40
# ETL Developer                40
# Blockchain                   40
# Arts                         36
# Database                     33
# Health and fitness           30
# Electrical Engineering       30
# PMO                          30
# ...

# %%
import pandas as pd
from pathlib import Path

csv_path = Path("Dataset/job_title_des.csv")
if not csv_path.exists():
    csv_path = Path(r"C:\Users\Acer\Documents\Programs\ResuMatch\Dataset\job_title_des.csv")
print(df.shape)
print(df.columns.tolist())
print(df.head(3))
print(df.isnull().sum())
print(df['Category'].value_counts())
# Out:
# (962, 2)
# ['Category', 'Resume']
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# Category    0
# Resume      0
# dtype: int64
# Category
# Java Developer               84
# Testing                      70
# DevOps Engineer              55
# Python Developer             48
# Web Designing                45
# HR                           44
# Hadoop                       42
# Data Science                 40
# Mechanical Engineer          40
# Sales                        40
# Operations Manager           40
# ETL Developer                40
# Blockchain                   40
# Arts                         36
# Database                     33
# Health and fitness           30
# Electrical Engineering       30
# PMO                          30
# ...

# %%
import pandas as pd

# Reuse the path already prepared in previous cells
if "csv_path" not in globals():
    csv_path = Path("Dataset/job_title_des.csv")
jobs_path = csv_path

if not jobs_path.exists():
    jobs_path = Path("Dataset/job_title_des.csv")

try:
    df_jobs = pd.read_csv(jobs_path)
except UnicodeDecodeError:
    df_jobs = pd.read_csv(jobs_path, encoding="latin1")

print(df_jobs.shape)
print(df_jobs.columns.tolist())
print(df_jobs.head(3))
print(df_jobs.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
# ----> 3 df_jobs = pd.read_csv('job_title_des.csv')
#       5 print(df_jobs.shape)
#       6 print(df_jobs.columns.tolist())
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
