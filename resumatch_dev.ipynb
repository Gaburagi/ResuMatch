# %%
import sys
# !{sys.executable} -m pip install nltk pandas scikit-learn numpy
# Out:
# Collecting nltk
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas in c:\Users\Acer\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.1)
# Requirement already satisfied: scikit-learn in c:\Users\Acer\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy in c:\Users\Acer\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.4.3)
# Requirement already satisfied: click in c:\Users\Acer\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (8.3.2)
# Requirement already satisfied: joblib in c:\Users\Acer\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.4.4-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Acer\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Acer\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\Acer\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\Acer\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in C:\Users\Acer\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in C:\Users\Acer\AppData\Roaming\Python\Python314\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# Downloading regex-2026.4.4-cp314-cp314-win_amd64.whl (280 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, nltk
#
#    ------------- -------------------------- 1/3 [regex]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    ---------------------------------------- 3/3 [nltk]
#
# Successfully installed nltk-3.9.4 regex-2026.4.4 tqdm-4.67.3

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# True

# %%
df_resumes = pd.read_csv('data/UpdatedResumeDataSet.csv')
df_jobs = pd.read_csv('data/job_title_des.csv')

df_jobs.drop(columns=['Unnamed: 0'], inplace=True)

print("Resumes:", df_resumes.shape)
print("Jobs:", df_jobs.shape)
# Out:
# Resumes: (962, 2)
# Jobs: (2277, 2)

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(w) for w in tokens if w not in stop_words]
    return ' '.join(tokens)

df_resumes['cleaned'] = df_resumes['Resume'].apply(clean_text)
df_jobs['cleaned'] = df_jobs['Job Description'].apply(clean_text)

print("✅ Cleaning done!")
print(df_resumes['cleaned'][0][:300])
